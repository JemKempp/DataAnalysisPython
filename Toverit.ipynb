# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('seaborn-whitegrid')

# %%
# Open the data
df = pd.read_excel('WorkPlaceSatisfactionSurveyData (3).xlsx')

# %%
df.head()
# Out:
#    number  gender  age  family  education  years_of_service  salary  \
# 0       1       1   38       1        1.0              22.0    3587
# 1       2       1   29       2        2.0              10.0    2963
# 2       3       1   30       1        1.0               7.0    1989
# 3       4       1   36       2        1.0              14.0    2144
# 4       5       1   24       1        2.0               4.0    2183
#
#    sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# 0               3            3.0                       3           3
# 1               1            5.0                       2           1
# 2               3            4.0                       1           1
# 3               3            3.0                       3           3
# 4               2            3.0                       2           1
#
#    sat_tasks  healtcare  holidayCabin  gym  muscleCare
# 0          3        NaN           NaN  NaN         NaN
# ...

# %%
df.isnull().sum()
# Out:
# number                     0
# gender                     0
# age                        0
# family                     0
# education                  1
# years_of_service           2
# salary                     0
# sat_management             0
# sat_colleques              1
# sat_workingEnvironment     0
# sat_salary                 0
# sat_tasks                  0
# healtcare                 35
# holidayCabin              62
# gym                       73
# muscleCare                60
# dtype: int64

# %%
df.columns = ['number', 'gender', 'age', 'family', 'education', 'years_of_service', 'salary', 'sat_management', 'sat_colleques', 'sat_workingEnvironment', 'sat_salary', 'sat_tasks', 'healthCare', 'holidayCabin', 'gym', 'muscleCare']

# %%
df.head()
# Out:
#    number  gender  age  family  education  years_of_service  salary  \
# 0       1       1   38       1        1.0              22.0    3587
# 1       2       1   29       2        2.0              10.0    2963
# 2       3       1   30       1        1.0               7.0    1989
# 3       4       1   36       2        1.0              14.0    2144
# 4       5       1   24       1        2.0               4.0    2183
#
#    sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# 0               3            3.0                       3           3
# 1               1            5.0                       2           1
# 2               3            4.0                       1           1
# 3               3            3.0                       3           3
# 4               2            3.0                       2           1
#
#    sat_tasks  healthCare  holidayCabin  gym  muscleCare
# 0          3         NaN           NaN  NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   number                  82 non-null     int64
#  1   gender                  82 non-null     int64
#  2   age                     82 non-null     int64
#  3   family                  82 non-null     int64
#  4   education               81 non-null     float64
#  5   years_of_service        80 non-null     float64
#  6   salary                  82 non-null     int64
#  7   sat_management          82 non-null     int64
#  8   sat_colleques           81 non-null     float64
#  9   sat_workingEnvironment  82 non-null     int64
#  10  sat_salary              82 non-null     int64
#  11  sat_tasks               82 non-null     int64
#  12  healthCare              47 non-null     float64
#  13  holidayCabin            20 non-null     float64
# ...

# %%
df.describe()
# Out:
#           number     gender        age     family  education  \
# count  82.000000  82.000000  82.000000  82.000000  81.000000
# mean   41.500000   1.231707  37.951220   1.621951   1.987654
# std    23.815261   0.424519   9.773866   0.487884   0.844006
# min     1.000000   1.000000  20.000000   1.000000   1.000000
# 25%    21.250000   1.000000  31.000000   1.000000   1.000000
# 50%    41.500000   1.000000  37.500000   2.000000   2.000000
# 75%    61.750000   1.000000  44.000000   2.000000   3.000000
# max    82.000000   2.000000  61.000000   2.000000   4.000000
#
#        years_of_service       salary  sat_management  sat_colleques  \
# count         80.000000    82.000000       82.000000      81.000000
# mean          12.175000  2563.878049        3.060976       4.061728
# std            8.807038   849.350302        1.058155       0.826826
# min            0.000000  1521.000000        1.000000       2.000000
# 25%            3.750000  2027.000000        2.000000       4.000000
# ...

# %%
df.count()
# Out:
# number                    82
# gender                    82
# age                       82
# family                    82
# education                 81
# years_of_service          80
# salary                    82
# sat_management            82
# sat_colleques             81
# sat_workingEnvironment    82
# sat_salary                82
# sat_tasks                 82
# healthCare                47
# holidayCabin              20
# gym                        9
# muscleCare                22
# dtype: int64

# %%
df.nlargest(n = 3, columns = 'age')
# Out:
#     number  gender  age  family  education  years_of_service  salary  \
# 56      57       1   61       2        2.0              36.0    3119
# 32      33       1   59       2        3.0              15.0    6278
# 13      14       1   58       2        3.0              21.0    3587
#
#     sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# 56               2            NaN                       2           1
# 32               4            4.0                       5           4
# 13               4            5.0                       4           1
#
#     sat_tasks  healthCare  holidayCabin  gym  muscleCare
# 56          5         1.0           NaN  NaN         1.0
# 32          4         NaN           1.0  NaN         NaN
# 13          3         NaN           NaN  NaN         NaN

# %%
df.nsmallest(n = 3, columns = 'age')
# Out:
#     number  gender  age  family  education  years_of_service  salary  \
# 58      59       1   20       1        2.0               1.0    2261
# 29      30       1   21       1        NaN               NaN    1949
# 30      31       1   21       1        3.0               1.0    2340
#
#     sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# 58               3            4.0                       3           2
# 29               4            4.0                       3           3
# 30               4            5.0                       3           4
#
#     sat_tasks  healthCare  holidayCabin  gym  muscleCare
# 58          3         NaN           NaN  NaN         NaN
# 29          2         1.0           NaN  NaN         NaN
# 30          2         1.0           NaN  1.0         1.0

# %%
df.nlargest(n = 5, columns = 'age')
# Out:
#     number  gender  age  family  education  years_of_service  salary  \
# 56      57       1   61       2        2.0              36.0    3119
# 32      33       1   59       2        3.0              15.0    6278
# 13      14       1   58       2        3.0              21.0    3587
# 27      28       2   56       1        1.0              15.0    2223
# 36      37       2   56       2        2.0              17.0    2729
#
#     sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# 56               2            NaN                       2           1
# 32               4            4.0                       5           4
# 13               4            5.0                       4           1
# 27               3            4.0                       3           2
# 36               5            5.0                       5           5
#
#     sat_tasks  healthCare  holidayCabin  gym  muscleCare
# 56          5         1.0           NaN  NaN         1.0
# ...

# %%
df_education_counts=pd.crosstab(df['education'], 'Count')

# %%
df_education_counts
# Out:
# col_0      Count
# education
# 1.0           27
# 2.0           30
# 3.0           22
# 4.0            2

# %%
df_education_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='education'>

# %%
df_gender_counts=pd.crosstab(df['gender'], 'Count')

# %%
df_gender_counts
# Out:
# col_0   Count
# gender
# 1          63
# 2          19

# %%
df_gender_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df_family_counts=pd.crosstab(df['family'], 'Count')

# %%
df_family_counts
# Out:
# col_0   Count
# family
# 1          31
# 2          51

# %%
df_family_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='family'>

# %%
df_age_counts=pd.crosstab(df['age'], 'Count')

# %%
df_age_counts
# Out:
# col_0  Count
# age
# 20         1
# 21         2
# 22         2
# 24         1
# 25         1
# 26         3
# 27         2
# 28         2
# 29         3
# 30         3
# 31         4
# 32         1
# 33         4
# 34         2
# 35         4
# 36         2
# 37         4
# 38         3
# 39         3
# 40         8
# 41         1
# 42         2
# 43         1
# 44         4
# 45         3
# 46         1
# 47         2
# 49         1
# 50         1
# 51         2
# 52         1
# 53         1
# 55         2
# 56         2
# 58         1
# 59         1
# 61         1

# %%
df_age_counts.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
min(df['age'])
# Out:
# 20

# %%
max(df['age'])
# Out:
# 61

# %%
bins = [20, 30, 40, 50, 60, 70]

# %%
df['age_class'] = pd.cut(df['age'], bins = bins)

# %%
df
# Out:
#     number  gender  age  family  education  years_of_service  salary  \
# 0        1       1   38       1        1.0              22.0    3587
# 1        2       1   29       2        2.0              10.0    2963
# 2        3       1   30       1        1.0               7.0    1989
# 3        4       1   36       2        1.0              14.0    2144
# 4        5       1   24       1        2.0               4.0    2183
# ..     ...     ...  ...     ...        ...               ...     ...
# 77      78       1   22       1        3.0               0.0    1598
# 78      79       1   33       1        1.0               2.0    1638
# 79      80       1   27       1        2.0               7.0    2612
# 80      81       1   35       2        2.0              16.0    2808
# 81      82       2   35       2        3.0              15.0    2183
#
#     sat_management  sat_colleques  sat_workingEnvironment  sat_salary  \
# ...

# %%
df1=pd.crosstab(df['age_class'], 'Count')

# %%
df1
# Out:
# col_0      Count
# age_class
# (20, 30]      19
# (30, 40]      35
# (40, 50]      16
# (50, 60]      10
# (60, 70]       1
